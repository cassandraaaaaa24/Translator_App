# %%
# !pip install chatterbot
# Out:
# Requirement already satisfied: chatterbot in c:\users\user\anaconda3\lib\site-packages (1.2.12)
# Requirement already satisfied: mathparse<0.3,>=0.2 in c:\users\user\anaconda3\lib\site-packages (from chatterbot) (0.2.7)
# Requirement already satisfied: python-dateutil<2.10,>=2.9 in c:\users\user\anaconda3\lib\site-packages (from chatterbot) (2.9.0.post0)
# Requirement already satisfied: sqlalchemy<2.1,>=2.0 in c:\users\user\anaconda3\lib\site-packages (from chatterbot) (2.0.43)
# Requirement already satisfied: spacy<3.9,>=3.8 in c:\users\user\anaconda3\lib\site-packages (from chatterbot) (3.8.11)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from chatterbot) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil<2.10,>=2.9->chatterbot) (1.17.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (0.24.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (2.12.4)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from spacy<3.9,>=3.8->chatterbot) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.9,>=3.8->chatterbot) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.9,>=3.8->chatterbot) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy<2.1,>=2.0->chatterbot) (3.2.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9,>=3.8->chatterbot) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<3.9,>=3.8->chatterbot) (0.1.5)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->chatterbot) (0.4.6)
# Requirement already satisfied: typer>=0.24.0 in c:\users\user\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (0.24.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<3.9,>=3.8->chatterbot) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\user\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<3.9,>=3.8->chatterbot) (7.5.1)
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy<3.9,>=3.8->chatterbot) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\user\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\user\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\user\anaconda3\lib\site-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy<3.9,>=3.8->chatterbot) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->spacy<3.9,>=3.8->chatterbot) (3.0.2)

# %%
# !pip install

# %%
# bot.py

from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
from cleaner import clean_corpus

CORPUS_FILE = "slacking_off.txt"

chatbot = ChatBot("Chatpot")

trainer = ListTrainer(chatbot)
cleaned_corpus = clean_corpus(CORPUS_FILE)
trainer.train(cleaned_corpus)

exit_conditions = (":q", "quit", "exit")
while True:
    query = input("> ")
    if query in exit_conditions:
        break
    else:
        print(f"🪴 {chatbot.get_response(query)}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 5
#       3 from chatterbot import ChatBot
#       4 from chatterbot.trainers import ListTrainer
# ----> 5 from cleaner import clean_corpus
#       7 CORPUS_FILE = "slacking_off.txt"
#       9 chatbot = ChatBot("Chatpot")
#
# ModuleNotFoundError: No module named 'cleaner'
